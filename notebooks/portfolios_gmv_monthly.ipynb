# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
# 1x3: CW, High Pref, Mid Pref, Low Pref
df_1x3 = pd.read_csv("../data/processed/monthly/monthly_1969_2024_ew_quantile_returns_1x3.csv",
                     index_col="date", parse_dates=True)

# 3x3: CW + 9 EBC x Pref portfolios
df_3x3 = pd.read_csv("../data/processed/monthly/monthly_1969_2024_ew_quantile_returns_3x3.csv",
                     index_col="date", parse_dates=True)

print("1x3 columns:", df_1x3.columns.tolist())
print("3x3 columns:", df_3x3.columns.tolist())
# Out:
# 1x3 columns: ['CW', 'High Pref', 'Mid Pref', 'Low Pref']
# 3x3 columns: ['CW', 'EBC_High_Pref_High', 'EBC_High_Pref_Mid', 'EBC_High_Pref_Low', 'EBC_Mid_Pref_High', 'EBC_Mid_Pref_Mid', 'EBC_Mid_Pref_Low', 'EBC_Low_Pref_High', 'EBC_Low_Pref_Mid', 'EBC_Low_Pref_Low']

# %% [markdown]
# ## GMV Optimizer & Backtest Engine

# %%
def gmv_weights(Sigma, ridge=1e-8, long_only=True):
    """Global Minimum Variance weights. Long-only by default."""
    n = Sigma.shape[0]
    Sigma = 0.5 * (Sigma + Sigma.T) + ridge * np.eye(n)

    def obj(w):
        return w @ Sigma @ w

    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]
    bounds = [(0, 1)] * n if long_only else [(None, None)] * n

    res = minimize(obj, np.ones(n) / n, method='SLSQP',
                   bounds=bounds, constraints=constraints)
    if not res.success:
        raise ValueError(res.message)
    return res.x


def run_gmv_backtest(df, rebalance_freq=3, lookback=36, use_full_history=False, min_obs=24):
    """
    Rolling GMV backtest on monthly data.

    Parameters
    ----------
    df             : DataFrame of monthly returns (columns = assets)
    rebalance_freq : months between rebalances
    lookback       : months of history for covariance (ignored if use_full_history=True)
    use_full_history: expanding window if True
    min_obs        : minimum months before first allocation
    """
    df = df.dropna()
    cols = df.columns.tolist()

    wts = pd.DataFrame(np.nan, index=df.index, columns=cols, dtype=float)
    ret = pd.Series(np.nan, index=df.index, dtype=float)

    t = min_obs
    while t < len(df):
        train = df.iloc[:t] if use_full_history else df.iloc[max(0, t - lookback):t]

        Sigma = train.cov().values
        if not np.isfinite(Sigma).all():
            t += 1
            continue

        w = gmv_weights(Sigma)

        t_end = min(t + rebalance_freq, len(df))
        block = df.iloc[t:t_end]
        wts.iloc[t:t_end] = w
        ret.iloc[t:t_end] = block.values @ w

        t = t_end

    ret = ret.dropna()
    wts = wts.loc[ret.index]
    return ret, wts


def summary_stats(ret, freq=12):
    """Annualized stats for a monthly return series."""
    ann_ret = (1 + ret.mean()) ** freq - 1
    ann_vol = ret.std() * np.sqrt(freq)
    sharpe  = ann_ret / ann_vol
    cum     = (1 + ret).prod() - 1
    logcum  = np.log1p(ret).cumsum()
    max_dd  = (logcum - logcum.cummax()).min()
    return pd.Series({
        'Ann. Return':  ann_ret,
        'Ann. Vol':     ann_vol,
        'Sharpe':       sharpe,
        'Cum. Return':  cum,
        'Max DD (log)': max_dd
    })


def plot_2asset_gmv(ret, wts, asset_a, asset_b, label_a, label_b, title_suffix):
    """Standard 3-panel plot for a 2-asset GMV backtest."""
    idx = ret.index
    fig, axes = plt.subplots(3, 1, figsize=(13, 12))

    # cumulative log-wealth
    ax = axes[0]
    for s, lbl in [(asset_a.loc[idx], label_a),
                   (asset_b.loc[idx], label_b),
                   (ret, ret.name)]:
        ax.plot(np.log1p(s).cumsum(), label=lbl)
    ax.set_title(f"Cumulative Log-Wealth – {title_suffix}")
    ax.set_ylabel("Log Wealth"); ax.legend(); ax.grid(True)

    # weight allocation
    ax = axes[1]
    ax.stackplot(wts.index, wts[label_a], wts[label_b], labels=[label_a, label_b])
    ax.set_title(f"GMV Weight Allocation – {title_suffix}")
    ax.set_ylabel("Weight"); ax.legend(loc="upper left"); ax.grid(True)

    # rolling 12M correlation
    ax = axes[2]
    roll_corr = asset_a.rolling(12).corr(asset_b)
    ax.plot(roll_corr)
    ax.axhline(0, linestyle="--", color="gray")
    ax.set_title(f"Rolling 12-Month Correlation: {label_a} vs {label_b}")
    ax.set_ylabel("Correlation"); ax.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Backtest Settings

# %%
REBAL     = 3      # rebalance every 3 months
LOOKBACK  = 36     # 3-year rolling covariance window
FULL_HIST = False  # True = expanding window; False = rolling LOOKBACK
MIN_OBS   = 24     # minimum months before first rebalance

# %% [markdown]
# ---
# ## Case 1: CW + Low Pref

# %%
df_1x3
# Out:
#                   CW  High Pref  Mid Pref  Low Pref
# date
# 1970-03-01  0.002794  -0.003289  0.011353  0.017250
# 1970-04-01 -0.088432  -0.108184 -0.100576 -0.100292
# 1970-05-01 -0.054689  -0.081717 -0.064843 -0.074185
# 1970-06-01 -0.048939  -0.052067 -0.043997 -0.061886
# 1970-07-01  0.075523   0.069523  0.087162  0.076948
# ...              ...        ...       ...       ...
# 2024-08-01  0.024283   0.019901  0.032476  0.023833
# 2024-09-01  0.022583   0.018824  0.030130  0.010950
# 2024-10-01 -0.008690  -0.022714 -0.003370 -0.024327
# 2024-11-01  0.060253   0.064798  0.061923  0.040448
# 2024-12-01 -0.023412  -0.040312 -0.071482 -0.072722
#
# [658 rows x 4 columns]

# %%
df_1x3

# %%
assets_c1 = df_1x3[["CW", "Low Pref"]].dropna()

ret_c1, wts_c1 = run_gmv_backtest(
    assets_c1, rebalance_freq=REBAL, lookback=LOOKBACK,
    use_full_history=FULL_HIST, min_obs=MIN_OBS
)
ret_c1.name = "GMV(CW+LowPref)"

print(f"Backtest: {ret_c1.index.min().date()} to {ret_c1.index.max().date()}  ({len(ret_c1)} months)")
wts_c1.tail()
# Out:
# Backtest: 1972-03-01 to 2024-12-01  (634 months)
#              CW  Low Pref
# date
# 2024-08-01  0.5       0.5
# 2024-09-01  0.5       0.5
# 2024-10-01  0.5       0.5
# 2024-11-01  0.5       0.5
# 2024-12-01  0.5       0.5

# %%
plot_2asset_gmv(
    ret_c1, wts_c1,
    assets_c1["CW"], assets_c1["Low Pref"],
    "CW", "Low Pref",
    "CW + Low Pref"
)

# %%
idx = ret_c1.index
pd.DataFrame({
    'CW':        summary_stats(assets_c1.loc[idx, 'CW']),
    'Low Pref':  summary_stats(assets_c1.loc[idx, 'Low Pref']),
    ret_c1.name: summary_stats(ret_c1),
}).T.round(4)
# Out:
#                  Ann. Return  Ann. Vol  Sharpe  Cum. Return  Max DD (log)
# CW                    0.1229    0.1531  0.8030     246.0030       -0.6984
# Low Pref              0.1600    0.1929  0.8294     960.6537       -0.8179
# GMV(CW+LowPref)       0.1238    0.1571  0.7881     247.1823       -0.7452

# %% [markdown]
# ---
# ## Case 2: CW + High EBC & Low Pref

# %%
assets_c2 = df_3x3[["CW", "EBC_High_Pref_Low"]].dropna()

ret_c2, wts_c2 = run_gmv_backtest(
    assets_c2, rebalance_freq=REBAL, lookback=LOOKBACK,
    use_full_history=FULL_HIST, min_obs=MIN_OBS
)
ret_c2.name = "GMV(CW+HighEBC_LowPref)"

print(f"Backtest: {ret_c2.index.min().date()} to {ret_c2.index.max().date()}  ({len(ret_c2)} months)")
wts_c2.tail()
# Out:
# Backtest: 1972-03-01 to 2024-12-01  (634 months)
#              CW  EBC_High_Pref_Low
# date
# 2024-08-01  1.0       1.110223e-16
# 2024-09-01  1.0       0.000000e+00
# 2024-10-01  1.0       0.000000e+00
# 2024-11-01  1.0       0.000000e+00
# 2024-12-01  1.0       5.551115e-17

# %%
plot_2asset_gmv(
    ret_c2, wts_c2,
    assets_c2["CW"], assets_c2["EBC_High_Pref_Low"],
    "CW", "EBC_High_Pref_Low",
    "CW + High EBC & Low Pref"
)

# %%
idx = ret_c2.index
pd.DataFrame({
    'CW':                  summary_stats(assets_c2.loc[idx, 'CW']),
    'EBC_High_Pref_Low':   summary_stats(assets_c2.loc[idx, 'EBC_High_Pref_Low']),
    ret_c2.name:           summary_stats(ret_c2),
}).T.round(4)
# Out:
#                          Ann. Return  Ann. Vol  Sharpe  Cum. Return  \
# CW                            0.1229    0.1531  0.8030     246.0030
# EBC_High_Pref_Low             0.1766    0.2427  0.7274    1151.5124
# GMV(CW+HighEBC_LowPref)       0.1223    0.1594  0.7675     226.2933
#
#                          Max DD (log)
# CW                            -0.6984
# EBC_High_Pref_Low             -0.8806
# GMV(CW+HighEBC_LowPref)       -0.6901

# %% [markdown]
# ---
# ## Case 3: CW + Mid EBC & Low Pref

# %%
assets_c3 = df_3x3[["CW", "EBC_Mid_Pref_Low"]].dropna()

ret_c3, wts_c3 = run_gmv_backtest(
    assets_c3, rebalance_freq=REBAL, lookback=LOOKBACK,
    use_full_history=FULL_HIST, min_obs=MIN_OBS
)
ret_c3.name = "GMV(CW+MidEBC_LowPref)"

print(f"Backtest: {ret_c3.index.min().date()} to {ret_c3.index.max().date()}  ({len(ret_c3)} months)")
wts_c3.tail()
# Out:
# Backtest: 1972-03-01 to 2024-12-01  (634 months)
#              CW  EBC_Mid_Pref_Low
# date
# 2024-08-01  0.5               0.5
# 2024-09-01  0.5               0.5
# 2024-10-01  0.5               0.5
# 2024-11-01  0.5               0.5
# 2024-12-01  0.5               0.5

# %%
plot_2asset_gmv(
    ret_c3, wts_c3,
    assets_c3["CW"], assets_c3["EBC_Mid_Pref_Low"],
    "CW", "EBC_Mid_Pref_Low",
    "CW + Mid EBC & Low Pref"
)

# %%
idx = ret_c3.index
pd.DataFrame({
    'CW':                 summary_stats(assets_c3.loc[idx, 'CW']),
    'EBC_Mid_Pref_Low':   summary_stats(assets_c3.loc[idx, 'EBC_Mid_Pref_Low']),
    ret_c3.name:          summary_stats(ret_c3),
}).T.round(4)
# Out:
#                         Ann. Return  Ann. Vol  Sharpe  Cum. Return  \
# CW                           0.1229    0.1531  0.8030      246.003
# EBC_Mid_Pref_Low             0.1567    0.1805  0.8683      931.646
# GMV(CW+MidEBC_LowPref)       0.1321    0.1603  0.8236      355.580
#
#                         Max DD (log)
# CW                           -0.6984
# EBC_Mid_Pref_Low             -0.6777
# GMV(CW+MidEBC_LowPref)       -0.6752

# %% [markdown]
# ---
# ## Comparison: All Three GMV Strategies vs CW

# %%
common_idx = ret_c1.index.intersection(ret_c2.index).intersection(ret_c3.index)
cw_common  = df_1x3.loc[common_idx, 'CW']

series = {
    'CW':          cw_common,
    ret_c1.name:   ret_c1.loc[common_idx],
    ret_c2.name:   ret_c2.loc[common_idx],
    ret_c3.name:   ret_c3.loc[common_idx],
}

fig, ax = plt.subplots(figsize=(13, 6))
for name, s in series.items():
    ax.plot(np.log1p(s).cumsum(), label=name)
ax.set_title("All GMV Strategies vs CW – Cumulative Log-Wealth")
ax.set_ylabel("Log Wealth"); ax.legend(); ax.grid(True)
plt.tight_layout()
plt.show()

pd.DataFrame({k: summary_stats(v) for k, v in series.items()}).T.round(4)
# Out:
#                          Ann. Return  Ann. Vol  Sharpe  Cum. Return  \
# CW                            0.1229    0.1531  0.8030     246.0030
# GMV(CW+LowPref)               0.1238    0.1571  0.7881     247.1823
# GMV(CW+HighEBC_LowPref)       0.1223    0.1594  0.7675     226.2933
# GMV(CW+MidEBC_LowPref)        0.1321    0.1603  0.8236     355.5800
#
#                          Max DD (log)
# CW                            -0.6984
# GMV(CW+LowPref)               -0.7452
# GMV(CW+HighEBC_LowPref)       -0.6901
# GMV(CW+MidEBC_LowPref)        -0.6752
