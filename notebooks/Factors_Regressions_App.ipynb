# %%
import yfinance as yf
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact
from IPython.display import HTML

from ipywidgets import (
    interactive_output, IntSlider, VBox, HBox, Checkbox, Dropdown, Label, Button
)
from IPython.display import display, HTML

import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
project_root = Path.cwd().parents[0]
sys.path.append(str(project_root))

import src.analysis.basic_analytics as ba
from arch import arch_model
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
from pathlib import Path
project_root = Path.cwd().parents[0]
sys.path.append(str(project_root))

DATA_PROCESSED_DIR = project_root / "data" / "processed"

# %% [markdown]
# EITHER 1996 OR 1966

# %%
start_date = "1996-10-01"
start_date = str(int(start_date[:4]) +3)
period = start_date + '_2024'

# %%
monthly_dir = DATA_PROCESSED_DIR / 'monthly'
df_monthly = pd.read_csv(
    monthly_dir / "monthly_preference_excess_returns_and_factors.csv", #"monthly_preferences_factors_quantiles.csv",
    index_col=0,
    parse_dates=True
)

# %%
quantile_monthly = pd.read_csv(
    monthly_dir / f"monthly_{period}_quantile_returns_3x3.csv",
    index_col = 0,
    parse_dates=True
)

# %%
df_monthly = df_monthly.join(
    quantile_monthly,
    how="inner"
)

# %%
df_monthly = df_monthly.rename(columns={
    "CW": "Cap-Weighted",
    "EW": "Equal-Weighted",
    "CW-EW": "Preference Portfolio: CW–EW",
    "EBC": "EBC",
    "CW-EBC": "Preference Portfolio: CW-EBC",

    # ---- Two-way quantile portfolios ----
    "EBC_Low_Pref_Low":   "Low EBC & Low Preference",
    "EBC_Low_Pref_Mid":   "Low EBC & Mid Preference",
    "EBC_Low_Pref_High":  "Low EBC & High Preference",

    "EBC_Mid_Pref_Low":   "Mid EBC & Low Preference",
    "EBC_Mid_Pref_Mid":   "Mid EBC & Mid Preference",
    "EBC_Mid_Pref_High":  "Mid EBC & High Preference",

    "EBC_High_Pref_Low":  "High EBC & Low Preference",
    "EBC_High_Pref_Mid":  "High EBC & Mid Preference",
    "EBC_High_Pref_High": "High EBC & High Preference"
})

# %%
df_monthly
# Out:
#             Cap-Weighted  Equal-Weighted       EBC  MKT_RF     SMB     HML  \
# date
# 2000-01-01     -0.037250       -0.061349 -0.062608 -0.0474  0.0421 -0.0112
# 2000-02-01      0.007184       -0.049399 -0.074209  0.0245  0.1846 -0.0977
# 2000-03-01      0.108160        0.105241  0.104334  0.0521 -0.1554  0.0850
# 2000-04-01     -0.021227        0.003474  0.015964 -0.0635 -0.0475  0.0645
# 2000-05-01     -0.012927        0.011657  0.022283 -0.0439 -0.0386  0.0459
# ...                  ...             ...       ...     ...     ...     ...
# 2024-08-01      0.023316        0.020143  0.025409  0.0161 -0.0355 -0.0110
# 2024-09-01      0.021856        0.019297  0.012079  0.0173 -0.0092 -0.0277
# 2024-10-01     -0.008686       -0.020310 -0.020416 -0.0100 -0.0089  0.0086
# 2024-11-01      0.062461        0.058051  0.051022  0.0649  0.0459  0.0015
# 2024-12-01     -0.018849       -0.066412 -0.065968 -0.0315 -0.0383 -0.0300
#
#                RMW     CMA      RF     MOM  ...  Preference Portfolio: CW-EBC  \
# 2024-12-01                   0.002961                 -0.078607
#
#             Low EBC & Low Preference
# date
# 2000-01-01                 -0.007951
# 2000-02-01                 -0.097953
# 2000-03-01                  0.081924
# 2000-04-01                  0.041043
# 2000-05-01                  0.037932
# ...                              ...
# 2024-08-01                  0.040292
# 2024-09-01                 -0.000691
# 2024-10-01                 -0.003944
# 2024-11-01                  0.017557
# 2024-12-01                 -0.066786
#
# [300 rows x 21 columns]

# %% [markdown]
# ## Daily

# %%
daily_dir = DATA_PROCESSED_DIR / 'daily'

# %%
df_daily = pd.read_csv(
    daily_dir / "daily_preference_excess_returns_and_factors.csv",
    index_col=0,
    parse_dates=True
)

# %%
quantile_daily = pd.read_csv(
    daily_dir / f"daily_{period}_quantile_returns_3x3.csv",
    #DATA_PROCESSED_DIR / "daily_quantile_returns.csv",
    index_col = 0,
    parse_dates=True
)

# %%
df_daily = df_daily.join(
    quantile_daily,
    how="inner"
)

# %%
df_daily = df_daily.rename(columns={
    "CW": "Cap-Weighted",
    "EW": "Equal-Weighted",
    "CW-EW": "Preference Portfolio: CW–EW",
    "EBC": "EBC",
    "CW-EBC": "Preference Portfolio: CW-EBC",

    # ---- Two-way quantile portfolios ----
    "EBC_Low_Pref_Low":   "Low EBC & Low Preference",
    "EBC_Low_Pref_Mid":   "Low EBC & Mid Preference",
    "EBC_Low_Pref_High":  "Low EBC & High Preference",

    "EBC_Mid_Pref_Low":   "Mid EBC & Low Preference",
    "EBC_Mid_Pref_Mid":   "Mid EBC & Mid Preference",
    "EBC_Mid_Pref_High":  "Mid EBC & High Preference",

    "EBC_High_Pref_Low":  "High EBC & Low Preference",
    "EBC_High_Pref_Mid":  "High EBC & Mid Preference",
    "EBC_High_Pref_High": "High EBC & High Preference"
})

# %%
df_daily
# Out:
#             Cap-Weighted  Equal-Weighted       EBC  MKT_RF     SMB     HML  \
# date
# 2000-01-04     -0.037983       -0.026701 -0.022588 -0.0406  0.0034  0.0207
# 2000-01-05      0.001782        0.004436  0.006811 -0.0009  0.0036 -0.0005
# 2000-01-06     -0.000576        0.011114  0.013943 -0.0074 -0.0004  0.0124
# 2000-01-07      0.033499        0.022717  0.021067  0.0321 -0.0089 -0.0157
# 2000-01-10      0.013774        0.004177  0.000535  0.0175  0.0043 -0.0135
# ...                  ...             ...       ...     ...     ...     ...
# 2024-12-24      0.011281        0.007606  0.007387  0.0111 -0.0012 -0.0006
# 2024-12-26     -0.000546        0.000847  0.001163  0.0001  0.0107 -0.0018
# 2024-12-27     -0.011224       -0.007275 -0.006728 -0.0117 -0.0044  0.0057
# 2024-12-30     -0.010923       -0.010046 -0.009459 -0.0109  0.0025  0.0074
# 2024-12-31     -0.004328        0.001478  0.002483 -0.0046  0.0032  0.0071
#
#                RMW     CMA      RF     MOM  ...  Preference Portfolio: CW-EBC  \
# date                                        ...
# 2000-01-04  0.0053  0.0136  0.0002 -0.0191  ...                     -0.015395
# 2000-01-04                 -0.010922
# 2000-01-05                  0.010485
# 2000-01-06                  0.021864
# 2000-01-07                  0.014986
# 2000-01-10                 -0.008985
# ...                              ...
# 2024-12-24                  0.003045
# 2024-12-26                  0.000150
# 2024-12-27                 -0.001894
# 2024-12-30                 -0.009381
# 2024-12-31                  0.006340
#
# [6288 rows x 21 columns]

# %%
# Define options
factor_options = ["MKT_RF", "SMB", "HML", "RMW", "CMA", "MOM"]
metric_options = ["Mean", "Std Dev", "r_squared", "alpha_tstat", "alpha_pval", "sortino"]
y_options = [
    "Cap-Weighted",
    "Equal-Weighted",
    "Preference Portfolio: CW–EW",
    "EBC",
    "Preference Portfolio: CW-EBC",

    # ---- Two-way quantile portfolios ----
    "Low EBC & Low Preference",
    "Low EBC & Mid Preference",
    "Low EBC & High Preference",

    "Mid EBC & Low Preference",
    "Mid EBC & Mid Preference",
    "Mid EBC & High Preference",

    "High EBC & Low Preference",
    "High EBC & Mid Preference",
    "High EBC & High Preference",
]

frequency_options = ['monthly','daily']

# %%
# Helper functions
def create_checkboxes(options, default=[]):
    return [Checkbox(value=(opt in default), description=opt, indent=False) for opt in options]

def get_selected_options(checkboxes):
    return [cb.description for cb in checkboxes if cb.value]

# Create widgets
factor_checkboxes = create_checkboxes(factor_options, default=["SMB", "HML", "RMW", "CMA", "MOM"])
metric_checkboxes = create_checkboxes(metric_options, default=["Mean", "Std Dev"])
y_selector = Dropdown(options=y_options, value="Preference Portfolio: CW-EBC", description="Portfolio")
frequency_selector = Dropdown(options = frequency_options, value = 'monthly', description = 'Frequency')
window_slider = IntSlider(min=6, max=600, step=1, value=36, description="Window")
run_button = Button(description="Run", button_style='success')

############# additional graphs with market comparison and rolling stats #############

compare_to_market_checkbox = Checkbox(value=True, description="Compare to Market (Cap-Weighted)", indent=False)
show_fitted_GARCH_checkbox = Checkbox(value = True, description = "Show Fitted GARCH (conditional vol, and SR) of selected portfolio", indent = False)

# %%
# Store output to update
output_area = widgets.Output()

# %%
def fit_garch_model(returns):
    """
    Fit GARCH(1,1) with student t errors
    """

    returns = returns.dropna()

    # Scale to percentage
    returns_scaled = returns * 100

    am = arch_model(
        returns_scaled,
        mean="Constant",
        vol="GARCH",
        p=1,
        q=1,
        dist="t"
    )

    res = am.fit(disp="off")

    return res

# %%
# Define wrapped function for plotting
def wrapped_plot_rolling(button=None):  # optional param for button click
    with output_area:
        output_area.clear_output()
        factors = get_selected_options(factor_checkboxes)
        table_metrics = get_selected_options(metric_checkboxes)
        y_var = y_selector.value
        window = window_slider.value
        frequency = frequency_selector.value

        if frequency == 'monthly':
            df_2_use = df_monthly
        else:
            df_2_use = df_daily

        selected_df = ba.compute_rolling_betas_and_alpha(
            df_2_use,
            portfolio_col=y_var,
            window=window,
            beta_MKT="MKT_RF" in factors,
            beta_SMB="SMB" in factors,
            beta_HML="HML" in factors,
            beta_RMW="RMW" in factors,
            beta_CMA="CMA" in factors,
            beta_Momentum="MOM" in factors
        )
        market_df = ba.compute_rolling_betas_and_alpha(
            df_2_use,
            portfolio_col="Cap-Weighted", 
            window=window,
            beta_MKT="MKT_RF" in factors,
            beta_SMB="SMB" in factors,
            beta_HML="HML" in factors,
            beta_RMW="RMW" in factors,
            beta_CMA="CMA" in factors,
            beta_Momentum="MOM" in factors
            )

        
        df_2_use['Diff'] = df_2_use["Cap-Weighted"] - df_2_use[y_var]
        difference_df = ba.compute_rolling_betas_and_alpha(
            df_2_use,
            portfolio_col='Diff',
            window=window,
            beta_MKT="MKT_RF" in factors,
            beta_SMB="SMB" in factors,
            beta_HML="HML" in factors,
            beta_RMW="RMW" in factors,
            beta_CMA="CMA" in factors,
            beta_Momentum="MOM" in factors
        )

        freq_name = "Month" if frequency == "monthly" else "Day"

        # Plot rolling alpha and betas
        plot_cols = ["alpha"] + [f"beta_{f}" for f in factors if f"beta_{f}" in selected_df.columns]
        if frequency == 'monthly':
            selected_df[plot_cols].plot(figsize=(12, 6), title=f"{window}-{freq_name} Rolling Alpha & Betas")
        else:
            selected_df[plot_cols].plot(figsize=(12, 6), title=f"{window}-{freq_name} Rolling Alpha & Betas")
        plt.grid(True)
        plt.tight_layout()
        plt.show()

        ## compare to market
        if compare_to_market_checkbox.value:
            fig, axes = plt.subplots(1, 3, figsize=(16, 6), sharey=True)

            # Plot selected portfolio
            selected_df[plot_cols].plot(ax=axes[0], legend=False)
            axes[0].set_title(f"{y_var}")
            axes[0].grid(True)

            # Plot market portfolio
            market_df[plot_cols].plot(ax=axes[1], legend=False)
            axes[1].set_title("Cap-weighted (Market)")
            axes[1].grid(True)

            # Plot difference
            difference_df[plot_cols].plot(ax=axes[2], legend = False)
            axes[2].set_title(f"Difference of Market - {y_var}")
            axes[2].grid(True)

            # Shared legend on top
            # After plotting on both axes:
            handles1, labels1 = axes[0].get_legend_handles_labels()
            handles2, labels2 = axes[1].get_legend_handles_labels()

            # Combine and deduplicate by label
            combined = dict(zip(labels1 + labels2, handles1 + handles2))

            # Title first
            fig.text(0.5, 1.12, "Selected Portfolio and Market Comparison", ha='center', fontsize=16, weight='bold')
            fig.suptitle(f"{window}-{freq_name} Rolling Alpha & Beta Comparison", fontsize=14, y=1.04)


            # Then a single legend with unique entries
            fig.legend(combined.values(), combined.keys(), loc='upper center', bbox_to_anchor=(0.5, 1.01), ncol=len(combined), fontsize=10)


            plt.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            
            # more graphs for comparison

            # Get raw excess return series for selected portfolio and market
            sel_returns = df_2_use[y_var]
            mkt_returns = df_2_use["Cap-Weighted"]

            diff_returns =  mkt_returns - sel_returns

            # Graph rolling correlation of selected portfolio and market
            rolling_corr = ba.compute_rolling_correlation(sel_returns, mkt_returns, window)

            plt.figure(figsize=(12,4))
            plt.plot(rolling_corr, color = '#444444')
            plt.axhline(0, linestyle="--")
            plt.title(f"{window}-{freq_name} Rolling Correlation: {y_var} vs Market")
            plt.grid(True)
            plt.tight_layout()
            plt.show()


            # Compute rolling metrics
            cum_sel, vol_sel, sharpe_sel = ba.compute_rolling_metrics(sel_returns, window, frequency)
            cum_mkt, vol_mkt, sharpe_mkt = ba.compute_rolling_metrics(mkt_returns, window, frequency)
            cum_diff, vol_diff, sharpe_diff = ba.compute_rolling_metrics(diff_returns, window, frequency)

            # Plot side-by-side pairs

            # --- Cumulative Returns ---
            fig, axes = plt.subplots(1, 3, figsize=(16, 4), sharey=True)
            axes[0].plot(cum_sel, label=y_var)
            axes[0].set_title(f"Cumulative Returns: {y_var}")
            axes[1].plot(cum_mkt, label="Cap-Weighted", color="orange")
            axes[1].set_title("Cumulative Returns: Market")
            axes[2].plot(cum_diff, label="Difference", color = "#444444")
            axes[2].set_title(f"Cumulative Returns: Market - {y_var}")
            for ax in axes:
                ax.grid(True)
                ax.set_ylabel("Log Return")
            plt.tight_layout()
            plt.show()

            # --- Rolling Volatility ---
            fig, axes = plt.subplots(1, 2, figsize=(16, 4), sharey=True)
            axes[0].plot(vol_sel, label=y_var)
            axes[0].set_title(f"{window}-{freq_name} Rolling Volatility (Annualized): {y_var}")
            axes[1].plot(vol_mkt, label="Cap-Weighted", color="orange")
            axes[1].set_title(f"{window}-{freq_name} Rolling Volatility (Annualized): Market")
            for ax in axes:
                ax.grid(True)
                ax.set_ylabel("Volatility")
            plt.tight_layout()
            plt.show()

            # --- Rolling Sharpe Ratio ---
            fig, axes = plt.subplots(1, 2, figsize=(16, 4), sharey=True)
            axes[0].plot(sharpe_sel, label=y_var)
            axes[0].set_title(f"{window}-{freq_name} Rolling Sharpe Ratio (RF=0): {y_var}")
            axes[1].plot(sharpe_mkt, label="Cap-Weighted", color="orange")
            axes[1].set_title(f"{window}-{freq_name} Rolling Sharpe Ratio (RF=0): Market")
            for ax in axes:
                ax.grid(True)
                ax.set_ylabel("Sharpe Ratio")
            plt.tight_layout()
            plt.show()

        # Fitted GARCH 

        if show_fitted_GARCH_checkbox.value:
            
            # Title first
            display(HTML(f""" <h2 style="text-align:center; margin-top:20px;"> {y_var} Fitted GARCH (1,1)</h2>"""))

            portfolio = df_2_use[y_var]

            garch_res = fit_garch_model(portfolio)
            #print(garch_res.summary())

            cond_vol = garch_res.conditional_volatility / 100  # scale back

            plt.figure(figsize=(12,4))
            plt.plot(cond_vol)
            plt.title(f" {y_var} - Conditional Volatility (GARCH)")
            plt.ylabel("Volatility")
            plt.grid(True)
            plt.show()


            mean_return = portfolio.mean()

            cond_sharpe = mean_return / cond_vol


            plt.figure(figsize=(12,4))
            plt.plot(cond_sharpe)
            plt.axhline(0, linestyle="--")
            plt.title(f"{y_var} Conditional Sharpe Ratio")
            plt.grid(True)
            plt.show()        


        # Summary table
        all_metrics = {
            "Mean": selected_df.mean(),
            "Std Dev": selected_df.std(),
            "r_squared": selected_df["r_squared"].mean() if "r_squared" in selected_df.columns else None,
            "alpha_tstat": selected_df["alpha_tstat"].mean() if "alpha_tstat" in selected_df.columns else None,
            "alpha_pval": selected_df["alpha_pval"].mean() if "alpha_pval" in selected_df.columns else None,
            "sortino": selected_df["sortino"].mean() if "sortino" in selected_df.columns else None
        }

        selected_metrics = {k: v for k, v in all_metrics.items() if k in table_metrics and v is not None}
        row_names = ["alpha"] + [f"beta_{f}" for f in factors if f"beta_{f}" in selected_df.columns]

        summary = pd.DataFrame({metric: selected_df[row_names].mean() if metric == "Mean"
                                else selected_df[row_names].std() if metric == "Std Dev"
                                else [selected_metrics[metric]] * len(row_names)
                                for metric in selected_metrics})

        summary.index = row_names
        summary = summary.round(4)

        global latest_summary_table
        latest_summary_table = summary

        #display(HTML("<h4>Average Results from Rolling Factor Model</h4>"))
        display(widgets.HTML("<h4>Average Results from Rolling Factor Model</h4>"))

        display(summary)

# %%
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import VBox

# Bind the run button
run_button.on_click(wrapped_plot_rolling)

ui = VBox([
    HBox([Label("Factors:"), VBox(factor_checkboxes)]),
    HBox([Label("Summary Columns:"), VBox(metric_checkboxes)]),
    y_selector,
    frequency_selector,
    compare_to_market_checkbox,
    show_fitted_GARCH_checkbox,
    window_slider,
    run_button,
    output_area
])

title_html = widgets.HTML(
    f"<h2 style='color:#003366;'>Rolling Factor Analysis App – Preference Portfolio Variants for period {period}</h2>"
)

instructions_html = widgets.HTML("""
<p><b>Instructions:</b> Select a portfolio (e.g., Cap-weighted, Equal-weighted, or a preference variant), 
choose the factors to include, set the rolling window, and click <b>Run</b> to generate plots and summary statistics.</p>
<p>Explore alpha, beta exposures, Sortino ratio, and R² over time.</p>
""")

display(VBox([title_html, instructions_html, ui]))
# Out:
# VBox(children=(HTML(value="<h2 style='color:#003366;'>Rolling Factor Analysis App – Preference Portfolio Varia…

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[0]
print(PROJECT_ROOT)
DATA_PROCESSED_DIR_KEN = PROJECT_ROOT / "data" / "processed" / "Ken"
# Out:
# /Users/evi/Desktop/Invesco_Research_Project

# %%
df_daily
# Out:
#             Cap-Weighted  Equal-Weighted       EBC  MKT_RF     SMB     HML  \
# date
# 2000-01-04     -0.037983       -0.026701 -0.022588 -0.0406  0.0034  0.0207
# 2000-01-05      0.001782        0.004436  0.006811 -0.0009  0.0036 -0.0005
# 2000-01-06     -0.000576        0.011114  0.013943 -0.0074 -0.0004  0.0124
# 2000-01-07      0.033499        0.022717  0.021067  0.0321 -0.0089 -0.0157
# 2000-01-10      0.013774        0.004177  0.000535  0.0175  0.0043 -0.0135
# ...                  ...             ...       ...     ...     ...     ...
# 2024-12-24      0.011281        0.007606  0.007387  0.0111 -0.0012 -0.0006
# 2024-12-26     -0.000546        0.000847  0.001163  0.0001  0.0107 -0.0018
# 2024-12-27     -0.011224       -0.007275 -0.006728 -0.0117 -0.0044  0.0057
# 2024-12-30     -0.010923       -0.010046 -0.009459 -0.0109  0.0025  0.0074
# 2024-12-24                   0.009277                  0.005499
# 2024-12-26                  -0.001268                  0.001415
# 2024-12-27                  -0.013888                 -0.003267
# 2024-12-30                  -0.009522                 -0.009123
# 2024-12-31                  -0.008753                  0.004186
#
#             Low EBC & Low Preference
# date
# 2000-01-04                 -0.010922
# 2000-01-05                  0.010485
# 2000-01-06                  0.021864
# 2000-01-07                  0.014986
# 2000-01-10                 -0.008985
# ...                              ...
# 2024-12-24                  0.003045
# 2024-12-26                  0.000150
# 2024-12-27                 -0.001894
# 2024-12-30                 -0.009381
# 2024-12-31                  0.006340
#
# [6288 rows x 21 columns]

# %%
df_daily.columns
# Out:
# Index(['Cap-Weighted', 'Equal-Weighted', 'EBC', 'MKT_RF', 'SMB', 'HML', 'RMW',
#        'CMA', 'RF', 'MOM', 'Preference Portfolio: CW–EW',
#        'Preference Portfolio: CW-EBC', 'High EBC & High Preference',
#        'High EBC & Mid Preference', 'High EBC & Low Preference',
#        'Mid EBC & High Preference', 'Mid EBC & Mid Preference',
#        'Mid EBC & Low Preference', 'Low EBC & High Preference',
#        'Low EBC & Mid Preference', 'Low EBC & Low Preference'],
#       dtype='object')

# %%
rolling = ba.compute_rolling_betas_and_alpha(df_daily,'Cap-Weighted',252,False,True,True,True,False,True)

# %%
rolling[['alpha', 'beta_SMB', 'beta_HML', 'beta_RMW','beta_MOM']]
# Out:
#                alpha  beta_SMB  beta_HML  beta_RMW  beta_MOM
# 2001-01-03  0.001939 -0.900667 -0.743347 -0.204607  0.257511
# 2001-01-04  0.002282 -0.878818 -0.790776 -0.237350  0.168378
# 2001-01-05  0.002283 -0.876079 -0.791636 -0.238153  0.164470
# 2001-01-08  0.002246 -0.875953 -0.797943 -0.232305  0.168582
# 2001-01-09  0.002221 -0.872587 -0.789721 -0.233804  0.168487
# ...              ...       ...       ...       ...       ...
# 2024-12-24  0.000847  0.338475 -0.232942 -0.183433  0.434949
# 2024-12-26  0.000875  0.337936 -0.231126 -0.185701  0.438346
# 2024-12-27  0.000842  0.331851 -0.228373 -0.186052  0.437918
# 2024-12-30  0.000824  0.334462 -0.230202 -0.186776  0.441100
# 2024-12-31  0.000775  0.331540 -0.234931 -0.195830  0.438841
#
# [6036 rows x 5 columns]

# %%
rolling[['alpha', 'beta_SMB', 'beta_HML', 'beta_RMW','beta_MOM']].to_csv(DATA_PROCESSED_DIR_KEN/'daily_CW_rolling_betas_2000_no_CMA.csv')

# %%
rolling.columns
# Out:
# Index(['alpha', 'r_squared', 'alpha_tstat', 'alpha_pval', 'sortino',
#        'beta_SMB', 'beta_HML', 'beta_RMW', 'beta_MOM'],
#       dtype='object')

# %%
plot_cols = ['alpha', 'beta_SMB', 'beta_HML', 'beta_RMW','beta_MOM']

# %%
rolling[plot_cols].plot(figsize=(12, 6), title=f"252-Daily Rolling Alpha & Betas")
# Out:
# <Axes: title={'center': '252-Daily Rolling Alpha & Betas'}>
