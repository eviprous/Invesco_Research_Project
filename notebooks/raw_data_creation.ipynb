# %% [markdown]
# # Notebook to get, store, and clean our data both from Fama French and CRSP

# %% [markdown]
# ### Get FF factors data

# %%
import sys
from pathlib import Path
import pandas as pd

# %%
project_root = Path.cwd().parents[0]
sys.path.append(str(project_root))

# %%
import src.data.load_factors as lf

# %% [markdown]
# #### Daily FF factors

# %%
ff_daily = lf.build_factors_dataset('daily')
ff_daily.head()
# Out:
#             MKT_RF     SMB     HML     RMW     CMA      RF     MOM
# date
# 1963-07-01 -0.0067  0.0000 -0.0034 -0.0001  0.0016  0.0001 -0.0023
# 1963-07-02  0.0079 -0.0026  0.0026 -0.0007 -0.0020  0.0001  0.0044
# 1963-07-03  0.0063 -0.0017 -0.0009  0.0018 -0.0034  0.0001  0.0038
# 1963-07-05  0.0040  0.0008 -0.0027  0.0009 -0.0034  0.0001  0.0006
# 1963-07-08 -0.0063  0.0004 -0.0018 -0.0029  0.0014  0.0001 -0.0045

# %% [markdown]
# #### Monthly FF factors

# %%
ff_monthly= lf.build_factors_dataset('monthly')
ff_monthly.head()
# Out:
#             MKT_RF     SMB     HML     RMW     CMA      RF     MOM
# date
# 1963-07-01 -0.0039 -0.0048 -0.0081  0.0064 -0.0115  0.0027  0.0101
# 1963-08-01  0.0508 -0.0080  0.0170  0.0040 -0.0038  0.0025  0.0100
# 1963-09-01 -0.0157 -0.0043  0.0000 -0.0078  0.0015  0.0027  0.0012
# 1963-10-01  0.0254 -0.0134 -0.0004  0.0279 -0.0225  0.0029  0.0313
# 1963-11-01 -0.0086 -0.0085  0.0173 -0.0043  0.0227  0.0027 -0.0078

# %% [markdown]
# ### Load CRSP data

# %%
import src.data.load_data as ld

# %% [markdown]
# #### Monthly CRSP Data

# %%
rets_m, caps_m = ld.build_crsp_dataset(frequency="monthly")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3300, in Engine.raw_connection(self)
#    3279 """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281 The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299 """
# -> 3300 return self.pool.connect()
#
# File /opt/anaconda3/lib/python3.12/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...

# %% [markdown]
# #### Daily CRSP Data

# %%
rets_d, caps_d = ld.build_crsp_dataset(start = "1960-01-01", end = "2025-12-31",frequency="daily")
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done
# [CRSP] Returns last date: 2024-12-31
# [CRSP] Market caps last date: 2024-12-31

# %% [markdown]
# ## Full Equity Universe Data Pull

# %%
import src.data.load_complete_data as lcd

# %% [markdown]
# #### Monthly Full Universe

# %%
rets_full_m, caps_full_m = lcd.build_complete_crsp_dataset(start="1960-01-01", end="2025-12-31")

# %% [markdown]
# ### Tiingo Full Equity Universe Data Pull
# *(Use while CRSP access is unavailable. Requires Tiingo Power plan ~$10/month.)*

# %%
import src.data.load_tiingo_data as lt

# %%
TIINGO_API_KEY = "your_api_key_here"  # replace with your key

rets_tiingo, caps_tiingo = lt.build_tiingo_dataset(
    api_key=TIINGO_API_KEY,
    start="1960-01-01",
    end="2025-12-31",
    fetch_market_caps=False   # set True if you have the Tiingo Fundamentals add-on
)
# Out:
# [Tiingo] Fetching supported tickers...
# [Tiingo] 22868 US stocks found in ticker list
# Fetching Tiingo prices:   8%|▊         | 1812/22868 [00:17<03:26, 101.91it/s]

# %%
TIINGO_API_KEY = "17afe31b55a4b2d6046d52ac825443a80a44e02d"  # replace with your key

rets_tiingo, caps_tiingo = lt.build_tiingo_dataset(
    api_key=TIINGO_API_KEY,
    start="1960-01-01",
    end="2025-12-31",
    fetch_market_caps=False   # set True if you have the Tiingo Fundamentals add-on
)
